# %%
# importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import  seaborn as sns
# Reading the data set to the Python Environment
data = pd.read_excel('/iris.xls')

# %%
# Displaying the columns in the Data set
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#Calculate the mean of each column of the data set
data.mean()
# Out:
# <ipython-input-56-acec91975b33>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
# Checking The Null Values Present the Data set
data.isnull()
# Out:
#         SL     SW     PL     PW  Classification
# 0    False  False  False  False           False
# 1    False  False  False  False           False
# 2    False  False  False  False           False
# 3    False  False  False  False           False
# 4    False  False  False  False           False
# ..     ...    ...    ...    ...             ...
# 145  False  False  False  False           False
# 146  False  False  False  False           False
# 147  False  False  False  False           False
# 148  False  False  False  False           False
# 149  False  False  False  False           False
#
# [150 rows x 5 columns]

# %%
#Code for Meaningful Visualisations using the data set
#visualisation 1
data.plot()
# Out:
# <Axes: >

# %%
#visualisation 2
data.plot(kind='box')
# Out:
# <Axes: >

# %%
#visualisation 3
data.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
